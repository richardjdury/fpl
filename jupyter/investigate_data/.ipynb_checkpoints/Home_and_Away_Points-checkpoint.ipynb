# %% [markdown]
# # Influence of home/away fixtures on points
#
# In this script, I will look at the distribution of points between home and away fixtures.
#
# #### Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# #### Read files

# %%
data = pd.read_csv('../../data/csv/data01.csv')
data.head()
# Out:
#   element_name  element  element_type  fixture          kickoff_time  \
# 0         Cech        0             0        0  2018-08-12T15:00:00Z
# 1         Cech        0             0       13  2018-08-18T16:30:00Z
# 2         Cech        0             0       20  2018-08-25T14:00:00Z
# 3         Cech        0             0       32  2018-09-02T12:30:00Z
# 4         Cech        0             0       45  2018-09-15T14:00:00Z
#
#    was_home  team  opponent_team  minutes  total_points
# 0      True     0             12       90             3
# 1     False     0              5       90             3
# 2      True     0             18       90             3
# 3     False     0              4       90             1
# 4     False     0             14       90             2

# %% [markdown]
# Look at only players who have played more than 89 minutes, and split by home/away matches.

# %%
valid_players = data[data['minutes']==90]
home_players = valid_players[valid_players['was_home']]
away_players = valid_players[~valid_players['was_home']]

# %%
plt.figure()
plt.boxplot(home_players['total_points'], positions=[0], widths=0.8);
plt.boxplot(away_players['total_points'], positions=[1], widths=0.8);
plt.xticks([0,1], labels=['Home', 'Away']);
plt.ylabel('Points');

# %%
home_points_mean = np.mean(home_players['total_points'])
home_points_std = np.std(home_players['total_points'])
print("Home Points: " + str(home_points_mean) + " +/- " + str(home_points_std))

away_points_mean = np.mean(away_players['total_points'])
away_points_std = np.std(away_players['total_points'])
print("Away Points: " + str(away_points_mean) + " +/- " + str(away_points_std))
# Out:
# Home Points: 3.740506329113924 +/- 3.334382412493317
# Away Points: 3.2092580849714647 +/- 3.005273829045467

# %%
stats.ttest_ind(home_players['total_points'], away_players['total_points'])
# Out:
# Ttest_indResult(statistic=6.6482803175580685, pvalue=3.213868150659119e-11)

# %%
cohens_d = (home_points_mean - away_points_mean) / (np.sqrt((home_points_std ** 2 + away_points_std ** 2) / 2))
print(cohens_d)
# Out:
# 0.16736991089956596

# %% [markdown]
# The p-value indicates a significant difference, however the Cohen's d value suggests a much smaller difference. As we might expect, there is a difference between points achieved at home and away overall. Now I will investigate if a particular position is responsible for this.

# %%
spx = 2
spy = 1
fig,ax = plt.subplots(spy,spx, figsize=(16,6))

# cohens_d
cd = np.zeros(4,dtype='float')
pv = np.zeros(4,dtype='float')

for i in range(4):
    h_points_position = home_players.loc[home_players['element_type']==i, 'total_points']
    a_points_position = away_players.loc[away_players['element_type']==i, 'total_points']
    
    ax[0].boxplot(h_points_position, positions=[i], widths=0.8)
    ax[1].boxplot(a_points_position, positions=[i], widths=0.8)
    cd[i] = (np.mean(h_points_position) - np.mean(a_points_position)) / (np.sqrt((np.std(h_points_position) ** 2 + np.std(a_points_position) ** 2) / 2))
    p = stats.ttest_ind(h_points_position, a_points_position)
    pv[i] = p.pvalue
    print(pv[i])
    
ax[0].set_xticklabels(['GKP', 'DEF', 'MID', 'FWD']);
ax[0].set_title('Home Points');
ax[1].set_xticklabels(['GKP', 'DEF', 'MID', 'FWD']);
ax[1].set_title('Away Points');
# Out:
# 0.20285147757139166
# 2.8880339758892386e-08
# 0.002322015357904343
# 0.09755164830025412

# %% [markdown]
# By investigating position, only defenders and midfielders are effects by the fixture being home or away. Goalkeepers are especially unaffected by the fixture being home or away. Forwards show trend towards achieving more points at home, but this is not signiicant.
#
# I will investigate this futher by separating by team.

# %% [markdown]
# #### Separate by team

# %%
# Fig
spx = 2
spy = 20
fig,ax = plt.subplots(spy,spx, figsize=(10,80))

# Loop thotugh teams
for i in range(20):
    for j in range(4):
        
        h_points_position = home_players.loc[home_players['element_type']==j, :]
        h_points_position_team = h_points_position.loc[h_points_position['team']==i, 'total_points']
        a_points_position = away_players.loc[away_players['element_type']==j, :]
        a_points_position_team = a_points_position.loc[a_points_position['team']==i, 'total_points']
        
        [x,y] = np.unravel_index()
