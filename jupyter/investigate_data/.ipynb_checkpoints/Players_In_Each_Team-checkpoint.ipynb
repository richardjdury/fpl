# %%
# Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
elements = pd.read_csv('../../data/csv/elements.csv')
elements.head()
# Out:
#    id  team  element_type first_name second_name   web_name
# 0   0     0             0       Petr        Cech       Cech
# 1   1     0             0      Bernd        Leno       Leno
# 2   2     0             1    Laurent   Koscielny  Koscielny
# 3   3     0             1     Hector    Bellerin   Bellerin
# 4   4     0             1      Nacho     Monreal    Monreal

# %%
players_in_team = np.zeros(20, dtype='int')

for i in range(20):
    players_in_team[i] = sum(elements.loc[:,'team']==i)
    print("Team " + str(i) + ": " + str(players_in_team[i]))
# Out:
# Team 0: 32
# Team 1: 32
# Team 2: 31
# Team 3: 30
# Team 4: 31
# Team 5: 30
# Team 6: 32
# Team 7: 33
# Team 8: 31
# Team 9: 34
# Team 10: 31
# Team 11: 26
# Team 12: 25
# Team 13: 31
# Team 14: 34
# Team 15: 34
# Team 16: 32
# Team 17: 31
# Team 18: 35
# Team 19: 29

# %%
np.median(players_in_team)
# Out:
# 31.0

# %%
data = pd.read_csv('../../data/csv/data01_full.csv')
data.head()
# Out:
#      id          kickoff_time kickoff_time_formatted  team_h_score  \
# 0     1  2018-08-12T15:00:00Z           12 Aug 16:00             0
# 1   526  2018-08-18T16:30:00Z           18 Aug 17:30             3
# 2  1053  2018-08-25T14:00:00Z           25 Aug 15:00             3
# 3  1584  2018-09-02T12:30:00Z           02 Sep 13:30             2
# 4  2121  2018-09-15T14:00:00Z           15 Sep 15:00             1
#
#    team_a_score  was_home  round  total_points  value  transfers_balance  ...  \
# 0             2      True      1             3     50                  0  ...
# 1             2     False      2             3     50                188  ...
# 2             1      True      3             3     50               8540  ...
# 3             3     False      4             1     50               9582  ...
# 4             2     False      5             2     50              -3297  ...
#
#    offside  target_missed  fouls  dribbles  element  fixture  opponent_team  \
# ...

# %%
player_played = np.zeros(90, dtype='int')
mins = np.array(range(90))
for i in range(90):
    player_played[i] = sum(data['minutes']>i)
    
plt.figure(figsize=(12,8))
plt.plot(mins,player_played)
